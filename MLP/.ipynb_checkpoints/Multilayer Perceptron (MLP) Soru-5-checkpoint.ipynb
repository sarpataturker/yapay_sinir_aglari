# %%
import time
start = time.time()
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, TensorDataset
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import MultiLabelBinarizer
import pandas as pd
import numpy as np
import os

# %% [markdown]
# Seed değerimi giriyorum

# %%
torch.manual_seed(190401015)

# %% [markdown]
# MLP için class oluşturuyoruz.
#
# Creating new class for MLP

# %%
class MLP(nn.Module):
    def __init__(self, insize, hidden1, hidden2, outputsize):
        super(MLP, self).__init__()
        self.hidden_layer1 = nn.Linear(insize, hidden1)
        self.hidden_layer2 = nn.Linear(hidden1, hidden2)
        self.output_layer = nn.Linear(hidden2, outputsize)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        output = self.relu(self.hidden_layer1(x))
        output = self.relu(self.hidden_layer2(output))
        output = self.sigmoid(self.output_layer(output))
        return output

# %% [markdown]
# csv verimizi okuma
#
# reading the csv file

# %%
training_data = pd.read_csv("./cure_the_princess_train.csv")
val_data = pd.read_csv("./cure_the_princess_validation.csv")
test_data = pd.read_csv("./cure_the_princess_test.csv")
labels = training_data.columns.tolist()
num_of_classes = len(labels)
train_x = training_data.iloc[:, :-1].values
train_y = training_data.iloc[:, -1].values
val_x = val_data.iloc[:, :-1].values
val_y = val_data.iloc[:, -1].values
test_x = test_data.iloc[:, :-1].values
test_y = test_data.iloc[:, -1].values

# %% [markdown]
# CustomData adında class oluşturup okunan verilerimizi işleme
#
# Creating new class called CustomData for using our data

# %%
class CustomData(Dataset):
    def __init__(self, x, y):
        self.x = torch.tensor(x, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

train_data = CustomData(train_x, train_y)
validation_data = CustomData(val_x, val_y)
test_data = CustomData(test_x, test_y)

# %%
learning_rate = 0.00167
epochnum = 200
bsize = 16
insize = 13
hidden1 = 100
hidden2 = 50
outsize = 1
patience = 10

# %%
model = MLP(insize, hidden1, hidden2, outsize)

# %%
# Loss fonksiyonunu belirlemek / Determining loss function
criterion = nn.BCELoss()

# Optimizer'ı belirlemek / Determining optimizer
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

# %%
train_loader = torch.utils.data.DataLoader(train_data, batch_size=bsize, shuffle=True)
valid_loader = torch.utils.data.DataLoader(validation_data, batch_size=bsize, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=bsize, shuffle=False)

# %%
train_loss_list = []
valid_loss_list = []

# %%
patience_counter = 0
best_value_loss = None
for epoch in range(epochnum):
    train_loss = 0.0
    train_count = 0.0
    valid_loss = 0.0

    # Eğitim verileri üzerinde eğitim yapmak / Training
    for data, target in train_loader:
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target.unsqueeze(1).float())
        loss.backward()
        optimizer.step()
        train_count += 1
        train_loss += loss.item()

    # Doğrulama verileri üzerinde test yapmak / Testing
    with torch.no_grad():
        model.eval()
        for data, target in valid_loader:
            output = model(data)
            loss = criterion(output, target.unsqueeze(1).float())
            valid_loss += loss.item()
    
    model.train()
    # Loss değerlerini kaydetmek / Saving the Loss values
    train_loss = train_loss / train_count
    valid_loss = valid_loss / len(valid_loader)
        
    train_loss_list.append(train_loss)
    valid_loss_list.append(valid_loss)
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch + 1, train_loss, valid_loss))
    
    val_score = valid_loss
    if best_value_loss is None:
        best_value_loss = val_score # hafızada patience boyu tutmaya başla
        torch.save(model.state_dict(), "checkpoint.pt")
    elif best_value_loss < val_score: # patience counter
        patience_counter = patience_counter + 1
        print("Earlystopping Patience Counter:",patience_counter)
        if patience_counter == patience:
            break
    else:
        best_value_loss = val_score
        torch.save(model.state_dict(), "checkpoint.pt") # to keep the best model
        patience_counter = 0
# Out:
# Epoch: 1 	Training Loss: 0.679726 	Validation Loss: 0.594903
# Epoch: 2 	Training Loss: 0.582686 	Validation Loss: 0.514434
# Epoch: 3 	Training Loss: 0.525498 	Validation Loss: 0.458775
# Epoch: 4 	Training Loss: 0.484742 	Validation Loss: 0.419505
# Epoch: 5 	Training Loss: 0.445706 	Validation Loss: 0.401848
# Epoch: 6 	Training Loss: 0.419666 	Validation Loss: 0.356211
# Epoch: 7 	Training Loss: 0.395933 	Validation Loss: 0.333594
# Epoch: 8 	Training Loss: 0.375798 	Validation Loss: 0.318667
# Epoch: 9 	Training Loss: 0.352688 	Validation Loss: 0.334290
# Earlystopping Patience Counter: 1
# Epoch: 10 	Training Loss: 0.336368 	Validation Loss: 0.298473
# Epoch: 11 	Training Loss: 0.326899 	Validation Loss: 0.296004
# Epoch: 12 	Training Loss: 0.314086 	Validation Loss: 0.272447
# Epoch: 13 	Training Loss: 0.304173 	Validation Loss: 0.265857
# Epoch: 14 	Training Loss: 0.294756 	Validation Loss: 0.336482
# Earlystopping Patience Counter: 1
# Epoch: 15 	Training Loss: 0.285755 	Validation Loss: 0.308048
# Earlystopping Patience Counter: 2
# Epoch: 16 	Training Loss: 0.282899 	Validation Loss: 0.233858
# Epoch: 17 	Training Loss: 0.270989 	Validation Loss: 0.383065
# Earlystopping Patience Counter: 1
# Epoch: 18 	Training Loss: 0.262964 	Validation Loss: 0.230949
# Epoch: 19 	Training Loss: 0.253108 	Validation Loss: 0.220237
# Epoch: 20 	Training Loss: 0.250622 	Validation Loss: 0.217571
# Epoch: 21 	Training Loss: 0.247429 	Validation Loss: 0.245884
# Earlystopping Patience Counter: 1
# Epoch: 22 	Training Loss: 0.240873 	Validation Loss: 0.213926
# Epoch: 23 	Training Loss: 0.236622 	Validation Loss: 0.208277
# Epoch: 24 	Training Loss: 0.231706 	Validation Loss: 0.229471
# Earlystopping Patience Counter: 1
# Epoch: 25 	Training Loss: 0.230281 	Validation Loss: 0.206645
# Epoch: 26 	Training Loss: 0.221832 	Validation Loss: 0.204402
# Epoch: 27 	Training Loss: 0.228705 	Validation Loss: 0.201553
# Epoch: 28 	Training Loss: 0.218406 	Validation Loss: 0.220244
# Earlystopping Patience Counter: 1
# Epoch: 29 	Training Loss: 0.223010 	Validation Loss: 0.235845
# Earlystopping Patience Counter: 2
# Epoch: 30 	Training Loss: 0.213939 	Validation Loss: 0.201233
# Epoch: 31 	Training Loss: 0.207981 	Validation Loss: 0.193464
# Epoch: 32 	Training Loss: 0.209333 	Validation Loss: 0.194400
# Earlystopping Patience Counter: 1
# Epoch: 33 	Training Loss: 0.204063 	Validation Loss: 0.187231
# Epoch: 34 	Training Loss: 0.195974 	Validation Loss: 0.191607
# Earlystopping Patience Counter: 1
# Epoch: 35 	Training Loss: 0.196710 	Validation Loss: 0.183574
# Epoch: 36 	Training Loss: 0.197541 	Validation Loss: 0.201695
# Earlystopping Patience Counter: 1
# Epoch: 37 	Training Loss: 0.190074 	Validation Loss: 0.184946
# Earlystopping Patience Counter: 2
# Epoch: 38 	Training Loss: 0.202107 	Validation Loss: 0.258494
# Earlystopping Patience Counter: 3
# Epoch: 39 	Training Loss: 0.190132 	Validation Loss: 0.199158
# Earlystopping Patience Counter: 4
# Epoch: 40 	Training Loss: 0.186160 	Validation Loss: 0.201536
# Earlystopping Patience Counter: 5
# Epoch: 41 	Training Loss: 0.186214 	Validation Loss: 0.191139
# Earlystopping Patience Counter: 6
# Epoch: 42 	Training Loss: 0.184154 	Validation Loss: 0.211951
# Earlystopping Patience Counter: 7
# Epoch: 43 	Training Loss: 0.179063 	Validation Loss: 0.190757
# Earlystopping Patience Counter: 8
# Epoch: 44 	Training Loss: 0.174906 	Validation Loss: 0.177737
# Epoch: 45 	Training Loss: 0.175676 	Validation Loss: 0.180831
# Earlystopping Patience Counter: 1
# Epoch: 46 	Training Loss: 0.173699 	Validation Loss: 0.177231
# Epoch: 47 	Training Loss: 0.172042 	Validation Loss: 0.177104
# Epoch: 48 	Training Loss: 0.169456 	Validation Loss: 0.174782
# Epoch: 49 	Training Loss: 0.169244 	Validation Loss: 0.171481
# Epoch: 50 	Training Loss: 0.174620 	Validation Loss: 0.190021
# Earlystopping Patience Counter: 1
# Epoch: 51 	Training Loss: 0.168163 	Validation Loss: 0.174507
# Earlystopping Patience Counter: 2
# Epoch: 52 	Training Loss: 0.162875 	Validation Loss: 0.182104
# Earlystopping Patience Counter: 3
# Epoch: 53 	Training Loss: 0.164524 	Validation Loss: 0.175917
# Earlystopping Patience Counter: 4
# Epoch: 54 	Training Loss: 0.158741 	Validation Loss: 0.188733
# Earlystopping Patience Counter: 5
# Epoch: 55 	Training Loss: 0.159020 	Validation Loss: 0.182701
# Earlystopping Patience Counter: 6
# Epoch: 56 	Training Loss: 0.157661 	Validation Loss: 0.170993
# Epoch: 57 	Training Loss: 0.156075 	Validation Loss: 0.166336
# Epoch: 58 	Training Loss: 0.156304 	Validation Loss: 0.173734
# Earlystopping Patience Counter: 1
# Epoch: 59 	Training Loss: 0.150045 	Validation Loss: 0.169761
# Earlystopping Patience Counter: 2
# Epoch: 60 	Training Loss: 0.151584 	Validation Loss: 0.168498
# Earlystopping Patience Counter: 3
# Epoch: 61 	Training Loss: 0.157263 	Validation Loss: 0.199885
# Earlystopping Patience Counter: 4
# Epoch: 62 	Training Loss: 0.154541 	Validation Loss: 0.167827
# Earlystopping Patience Counter: 5
# Epoch: 63 	Training Loss: 0.149316 	Validation Loss: 0.163869
# Epoch: 64 	Training Loss: 0.146349 	Validation Loss: 0.179396
# Earlystopping Patience Counter: 1
# Epoch: 65 	Training Loss: 0.147740 	Validation Loss: 0.173157
# Earlystopping Patience Counter: 2
# Epoch: 66 	Training Loss: 0.151510 	Validation Loss: 0.167613
# Earlystopping Patience Counter: 3
# Epoch: 67 	Training Loss: 0.147343 	Validation Loss: 0.165967
# Earlystopping Patience Counter: 4
# Epoch: 68 	Training Loss: 0.146324 	Validation Loss: 0.162488
# Epoch: 69 	Training Loss: 0.147894 	Validation Loss: 0.216930
# Earlystopping Patience Counter: 1
# Epoch: 70 	Training Loss: 0.142650 	Validation Loss: 0.175719
# Earlystopping Patience Counter: 2
# Epoch: 71 	Training Loss: 0.141032 	Validation Loss: 0.159254
# Epoch: 72 	Training Loss: 0.139819 	Validation Loss: 0.163236
# Earlystopping Patience Counter: 1
# Epoch: 73 	Training Loss: 0.138877 	Validation Loss: 0.163459
# Earlystopping Patience Counter: 2
# Epoch: 74 	Training Loss: 0.138990 	Validation Loss: 0.166334
# Earlystopping Patience Counter: 3
# Epoch: 75 	Training Loss: 0.136695 	Validation Loss: 0.188877
# Earlystopping Patience Counter: 4
# Epoch: 76 	Training Loss: 0.136836 	Validation Loss: 0.163601
# Earlystopping Patience Counter: 5
# Epoch: 77 	Training Loss: 0.138713 	Validation Loss: 0.216107
# Earlystopping Patience Counter: 6
# Epoch: 78 	Training Loss: 0.135939 	Validation Loss: 0.158696
# Epoch: 79 	Training Loss: 0.129375 	Validation Loss: 0.156750
# Epoch: 80 	Training Loss: 0.135211 	Validation Loss: 0.163023
# Earlystopping Patience Counter: 1
# Epoch: 81 	Training Loss: 0.132915 	Validation Loss: 0.221141
# Earlystopping Patience Counter: 2
# Epoch: 82 	Training Loss: 0.132561 	Validation Loss: 0.159389
# Earlystopping Patience Counter: 3
# Epoch: 83 	Training Loss: 0.131720 	Validation Loss: 0.171865
# Earlystopping Patience Counter: 4
# Epoch: 84 	Training Loss: 0.130322 	Validation Loss: 0.159064
# Earlystopping Patience Counter: 5
# Epoch: 85 	Training Loss: 0.127934 	Validation Loss: 0.159839
# Earlystopping Patience Counter: 6
# Epoch: 86 	Training Loss: 0.125365 	Validation Loss: 0.155939
# Epoch: 87 	Training Loss: 0.125898 	Validation Loss: 0.159971
# Earlystopping Patience Counter: 1
# Epoch: 88 	Training Loss: 0.128008 	Validation Loss: 0.231186
# Earlystopping Patience Counter: 2
# Epoch: 89 	Training Loss: 0.126297 	Validation Loss: 0.157355
# Earlystopping Patience Counter: 3
# Epoch: 90 	Training Loss: 0.124520 	Validation Loss: 0.158462
# Earlystopping Patience Counter: 4
# Epoch: 91 	Training Loss: 0.123897 	Validation Loss: 0.172737
# Earlystopping Patience Counter: 5
# Epoch: 92 	Training Loss: 0.123074 	Validation Loss: 0.160493
# Earlystopping Patience Counter: 6
# Epoch: 93 	Training Loss: 0.120308 	Validation Loss: 0.157548
# Earlystopping Patience Counter: 7
# Epoch: 94 	Training Loss: 0.122461 	Validation Loss: 0.158532
# Earlystopping Patience Counter: 8
# Epoch: 95 	Training Loss: 0.120179 	Validation Loss: 0.176282
# Earlystopping Patience Counter: 9
# Epoch: 96 	Training Loss: 0.121994 	Validation Loss: 0.160481
# Earlystopping Patience Counter: 10
# Epoch: 97 	Training Loss: 0.119567 	Validation Loss: 0.155023
# Epoch: 98 	Training Loss: 0.117623 	Validation Loss: 0.157550
# Earlystopping Patience Counter: 1
# Epoch: 99 	Training Loss: 0.117144 	Validation Loss: 0.157867
# Earlystopping Patience Counter: 2
# Epoch: 100 	Training Loss: 0.116187 	Validation Loss: 0.161034
# Earlystopping Patience Counter: 3
# Epoch: 101 	Training Loss: 0.116935 	Validation Loss: 0.168300
# Earlystopping Patience Counter: 4
# Epoch: 102 	Training Loss: 0.112914 	Validation Loss: 0.163939
# Earlystopping Patience Counter: 5
# Epoch: 103 	Training Loss: 0.113303 	Validation Loss: 0.158191
# Earlystopping Patience Counter: 6
# Epoch: 104 	Training Loss: 0.115356 	Validation Loss: 0.165296
# Earlystopping Patience Counter: 7
# Epoch: 105 	Training Loss: 0.111406 	Validation Loss: 0.157175
# Earlystopping Patience Counter: 8
# Epoch: 106 	Training Loss: 0.110291 	Validation Loss: 0.161107
# Earlystopping Patience Counter: 9
# Epoch: 107 	Training Loss: 0.112580 	Validation Loss: 0.163498
# Earlystopping Patience Counter: 10
# Epoch: 108 	Training Loss: 0.110248 	Validation Loss: 0.168362
# Earlystopping Patience Counter: 11
# Epoch: 109 	Training Loss: 0.115433 	Validation Loss: 0.205954
# Earlystopping Patience Counter: 12
# Epoch: 110 	Training Loss: 0.109146 	Validation Loss: 0.152120
# Epoch: 111 	Training Loss: 0.107886 	Validation Loss: 0.152561
# Earlystopping Patience Counter: 1
# Epoch: 112 	Training Loss: 0.110163 	Validation Loss: 0.158750
# Earlystopping Patience Counter: 2
# Epoch: 113 	Training Loss: 0.109630 	Validation Loss: 0.171464
# Earlystopping Patience Counter: 3
# Epoch: 114 	Training Loss: 0.104288 	Validation Loss: 0.191300
# Earlystopping Patience Counter: 4
# Epoch: 115 	Training Loss: 0.108664 	Validation Loss: 0.162665
# Earlystopping Patience Counter: 5
# Epoch: 116 	Training Loss: 0.105633 	Validation Loss: 0.153662
# Earlystopping Patience Counter: 6
# Epoch: 117 	Training Loss: 0.104789 	Validation Loss: 0.156793
# Earlystopping Patience Counter: 7
# Epoch: 118 	Training Loss: 0.106987 	Validation Loss: 0.292976
# Earlystopping Patience Counter: 8
# Epoch: 119 	Training Loss: 0.107175 	Validation Loss: 0.154546
# Earlystopping Patience Counter: 9
# Epoch: 120 	Training Loss: 0.100857 	Validation Loss: 0.158578
# Earlystopping Patience Counter: 10
# Epoch: 121 	Training Loss: 0.103726 	Validation Loss: 0.161094
# Earlystopping Patience Counter: 11
# Epoch: 122 	Training Loss: 0.102411 	Validation Loss: 0.178665
# Earlystopping Patience Counter: 12
# Epoch: 123 	Training Loss: 0.103444 	Validation Loss: 0.211364
# Earlystopping Patience Counter: 13
# Epoch: 124 	Training Loss: 0.100744 	Validation Loss: 0.156295
# Earlystopping Patience Counter: 14
# Epoch: 125 	Training Loss: 0.099972 	Validation Loss: 0.154750
# Earlystopping Patience Counter: 15
# Epoch: 126 	Training Loss: 0.096748 	Validation Loss: 0.157590
# Earlystopping Patience Counter: 16
# Epoch: 127 	Training Loss: 0.099210 	Validation Loss: 0.160328
# Earlystopping Patience Counter: 17
# Epoch: 128 	Training Loss: 0.098993 	Validation Loss: 0.150314
# Epoch: 129 	Training Loss: 0.097159 	Validation Loss: 0.160152
# Earlystopping Patience Counter: 1
# Epoch: 130 	Training Loss: 0.097181 	Validation Loss: 0.155499
# Earlystopping Patience Counter: 2
# Epoch: 131 	Training Loss: 0.099862 	Validation Loss: 0.331291
# Earlystopping Patience Counter: 3
# Epoch: 132 	Training Loss: 0.100326 	Validation Loss: 0.156264
# Earlystopping Patience Counter: 4
# Epoch: 133 	Training Loss: 0.094889 	Validation Loss: 0.151494
# Earlystopping Patience Counter: 5
# Epoch: 134 	Training Loss: 0.094682 	Validation Loss: 0.157539
# Earlystopping Patience Counter: 6
# Epoch: 135 	Training Loss: 0.091661 	Validation Loss: 0.173877
# Earlystopping Patience Counter: 7
# Epoch: 136 	Training Loss: 0.094461 	Validation Loss: 0.147471
# Epoch: 137 	Training Loss: 0.090690 	Validation Loss: 0.165252
# Earlystopping Patience Counter: 1
# Epoch: 138 	Training Loss: 0.094870 	Validation Loss: 0.157973
# Earlystopping Patience Counter: 2
# Epoch: 139 	Training Loss: 0.093554 	Validation Loss: 0.150204
# Earlystopping Patience Counter: 3
# Epoch: 140 	Training Loss: 0.089871 	Validation Loss: 0.152005
# Earlystopping Patience Counter: 4
# Epoch: 141 	Training Loss: 0.090178 	Validation Loss: 0.149970
# Earlystopping Patience Counter: 5
# Epoch: 142 	Training Loss: 0.090125 	Validation Loss: 0.155286
# Earlystopping Patience Counter: 6
# Epoch: 143 	Training Loss: 0.087936 	Validation Loss: 0.175886
# Earlystopping Patience Counter: 7
# Epoch: 144 	Training Loss: 0.088200 	Validation Loss: 0.152875
# Earlystopping Patience Counter: 8
# Epoch: 145 	Training Loss: 0.088106 	Validation Loss: 0.156654
# Earlystopping Patience Counter: 9
# Epoch: 146 	Training Loss: 0.085720 	Validation Loss: 0.157524
# Earlystopping Patience Counter: 10
# Epoch: 147 	Training Loss: 0.088323 	Validation Loss: 0.155083
# Earlystopping Patience Counter: 11
# Epoch: 148 	Training Loss: 0.087067 	Validation Loss: 0.151863
# Earlystopping Patience Counter: 12
# Epoch: 149 	Training Loss: 0.085002 	Validation Loss: 0.152611
# Earlystopping Patience Counter: 13
# Epoch: 150 	Training Loss: 0.084897 	Validation Loss: 0.154609
# Earlystopping Patience Counter: 14
# Epoch: 151 	Training Loss: 0.085175 	Validation Loss: 0.156622
# Earlystopping Patience Counter: 15
# Epoch: 152 	Training Loss: 0.083718 	Validation Loss: 0.150463
# Earlystopping Patience Counter: 16
# Epoch: 153 	Training Loss: 0.083395 	Validation Loss: 0.149214
# Earlystopping Patience Counter: 17
# Epoch: 154 	Training Loss: 0.083509 	Validation Loss: 0.157111
# Earlystopping Patience Counter: 18
# Epoch: 155 	Training Loss: 0.082703 	Validation Loss: 0.158660
# Earlystopping Patience Counter: 19
# Epoch: 156 	Training Loss: 0.081485 	Validation Loss: 0.161028
# Earlystopping Patience Counter: 20
# Epoch: 157 	Training Loss: 0.081079 	Validation Loss: 0.160643
# Earlystopping Patience Counter: 21
# Epoch: 158 	Training Loss: 0.081724 	Validation Loss: 0.171909
# Earlystopping Patience Counter: 22
# Epoch: 159 	Training Loss: 0.080803 	Validation Loss: 0.153604
# Earlystopping Patience Counter: 23
# Epoch: 160 	Training Loss: 0.079955 	Validation Loss: 0.425252
# Earlystopping Patience Counter: 24
# Epoch: 161 	Training Loss: 0.086486 	Validation Loss: 0.151949
# Earlystopping Patience Counter: 25
# Epoch: 162 	Training Loss: 0.079193 	Validation Loss: 0.155028
# Earlystopping Patience Counter: 26
# Epoch: 163 	Training Loss: 0.077343 	Validation Loss: 0.150941
# Earlystopping Patience Counter: 27
# Epoch: 164 	Training Loss: 0.079355 	Validation Loss: 0.153927
# Earlystopping Patience Counter: 28
# Epoch: 165 	Training Loss: 0.079023 	Validation Loss: 0.156862
# Earlystopping Patience Counter: 29
# Epoch: 166 	Training Loss: 0.076909 	Validation Loss: 0.153483
# Earlystopping Patience Counter: 30
# Epoch: 167 	Training Loss: 0.077665 	Validation Loss: 0.151704
# Earlystopping Patience Counter: 31
# Epoch: 168 	Training Loss: 0.076748 	Validation Loss: 0.168241
# Earlystopping Patience Counter: 32
# Epoch: 169 	Training Loss: 0.077907 	Validation Loss: 0.163948
# Earlystopping Patience Counter: 33
# Epoch: 170 	Training Loss: 0.077311 	Validation Loss: 0.159863
# Earlystopping Patience Counter: 34
# Epoch: 171 	Training Loss: 0.075612 	Validation Loss: 0.169116
# Earlystopping Patience Counter: 35
# Epoch: 172 	Training Loss: 0.073373 	Validation Loss: 0.149703
# Earlystopping Patience Counter: 36
# Epoch: 173 	Training Loss: 0.072995 	Validation Loss: 0.153908
# Earlystopping Patience Counter: 37
# Epoch: 174 	Training Loss: 0.074271 	Validation Loss: 0.155145
# Earlystopping Patience Counter: 38
# Epoch: 175 	Training Loss: 0.070367 	Validation Loss: 0.156376
# Earlystopping Patience Counter: 39
# Epoch: 176 	Training Loss: 0.070714 	Validation Loss: 0.157575
# Earlystopping Patience Counter: 40
# Epoch: 177 	Training Loss: 0.074388 	Validation Loss: 0.152008
# Earlystopping Patience Counter: 41
# Epoch: 178 	Training Loss: 0.075583 	Validation Loss: 0.220418
# Earlystopping Patience Counter: 42
# Epoch: 179 	Training Loss: 0.073720 	Validation Loss: 0.165339
# Earlystopping Patience Counter: 43
# Epoch: 180 	Training Loss: 0.069989 	Validation Loss: 0.171117
# Earlystopping Patience Counter: 44
# Epoch: 181 	Training Loss: 0.073140 	Validation Loss: 0.150122
# Earlystopping Patience Counter: 45
# Epoch: 182 	Training Loss: 0.072444 	Validation Loss: 0.153507
# Earlystopping Patience Counter: 46
# Epoch: 183 	Training Loss: 0.071721 	Validation Loss: 0.151889
# Earlystopping Patience Counter: 47
# Epoch: 184 	Training Loss: 0.069485 	Validation Loss: 0.154632
# Earlystopping Patience Counter: 48
# Epoch: 185 	Training Loss: 0.068857 	Validation Loss: 0.157089
# Earlystopping Patience Counter: 49
# Epoch: 186 	Training Loss: 0.066467 	Validation Loss: 0.159448
# Earlystopping Patience Counter: 50
# Epoch: 187 	Training Loss: 0.065363 	Validation Loss: 0.149211
# Earlystopping Patience Counter: 51
# Epoch: 188 	Training Loss: 0.067292 	Validation Loss: 0.165110
# Earlystopping Patience Counter: 52
# Epoch: 189 	Training Loss: 0.067927 	Validation Loss: 0.153628
# Earlystopping Patience Counter: 53
# Epoch: 190 	Training Loss: 0.066099 	Validation Loss: 0.157835
# Earlystopping Patience Counter: 54
# Epoch: 191 	Training Loss: 0.068119 	Validation Loss: 0.162381
# Earlystopping Patience Counter: 55
# Epoch: 192 	Training Loss: 0.069416 	Validation Loss: 0.149775
# Earlystopping Patience Counter: 56
# Epoch: 193 	Training Loss: 0.066450 	Validation Loss: 0.150359
# Earlystopping Patience Counter: 57
# Epoch: 194 	Training Loss: 0.065676 	Validation Loss: 0.155128
# Earlystopping Patience Counter: 58
# Epoch: 195 	Training Loss: 0.066602 	Validation Loss: 0.157257
# Earlystopping Patience Counter: 59
# Epoch: 196 	Training Loss: 0.062710 	Validation Loss: 0.159890
# Earlystopping Patience Counter: 60
# Epoch: 197 	Training Loss: 0.066047 	Validation Loss: 0.167562
# Earlystopping Patience Counter: 61
# Epoch: 198 	Training Loss: 0.063585 	Validation Loss: 0.163859
# Earlystopping Patience Counter: 62
# Epoch: 199 	Training Loss: 0.064847 	Validation Loss: 0.162702
# Earlystopping Patience Counter: 63
# Epoch: 200 	Training Loss: 0.065009 	Validation Loss: 0.159770
# Earlystopping Patience Counter: 64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
plt.plot(train_loss_list, label="Training loss")
plt.plot(valid_loss_list, label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

model.load_state_dict(torch.load('checkpoint.pt'))

preds = []
tlabels = []
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        outputs = model(inputs)
        predicted = torch.round(outputs)
        preds.extend(predicted.detach().cpu().numpy())
        tlabels.extend(labels.detach().cpu().numpy())

accuracy = accuracy_score(tlabels, preds)
f1 = f1_score(tlabels, preds)
precision = precision_score(tlabels, preds)
recall = recall_score(tlabels, preds)

print(f'Accuracy: {accuracy:.4f}')
print(f'F1 score: {f1:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
# Out:
# Accuracy: 0.9495
# F1 score: 0.9483
# Precision: 0.9755
# Recall: 0.9227

# %%
end = time.time()
elapsed = end - start
print("Elapsed:", f'{elapsed:.2f}', "secs")
# Out:
# Elapsed: 4.46 secs
